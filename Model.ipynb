# %%
import pandas as pd
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from tqdm.notebook import tqdm
warnings.filterwarnings('ignore')
# %matplotlib inline

import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.models import load_model
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, Input

# %%
datarute = 'UTKFace/'

# %%
image_paths = []
age_labels = []
gender_labels = []

for filename in os.listdir(datarute):
    image_path = os.path.join(datarute, filename)
    temp = filename.split('_')
    age = int(temp[0])
    gender = int(temp[1])
    image_paths.append(image_path)
    age_labels.append(age)
    gender_labels.append(gender)

# %%
df = pd.DataFrame()
df['image'], df['age'], df['gender'] = image_paths, age_labels, gender_labels
df.head()
# Out:
#                                             image  age  gender
# 0  UTKFace/100_0_0_20170112213500903.jpg.chip.jpg  100       0
# 1  UTKFace/100_0_0_20170112215240346.jpg.chip.jpg  100       0
# 2  UTKFace/100_1_0_20170110183726390.jpg.chip.jpg  100       1
# 3  UTKFace/100_1_0_20170112213001988.jpg.chip.jpg  100       1
# 4  UTKFace/100_1_0_20170112213303693.jpg.chip.jpg  100       1

# %%
def extract_features(images):
    features = []
    for image in images:
        img = load_img(image, grayscale=True)
        img = img.resize((128, 128), Image.ANTIALIAS)
        img = np.array(img)
        features.append(img)
        
    features = np.array(features)
    # ignore this step if using RGB
    features = features.reshape(len(features), 128, 128, 1)
    return features

# %%
X = extract_features(df['image'])

# %%
X.shape
# Out:
# (23708, 128, 128, 1)

# %%
X = X/255.0

# %%
y_gender = np.array(df['gender'])
y_age = np.array(df['age'])

# %%
age_ranges = [(0, 2), (3, 5), (6, 12), (13, 17), (18, 24), (25, 34), (35, 44), (45, 54), (55, 64), (65, 74), (75, 100)]

def age_to_range(age):
    for i, age_range in enumerate(age_ranges):
        if age >= age_range[0] and age <= age_range[1]:
            return i
    return len(age_ranges) - 1

y_age_range = np.array([age_to_range(age) for age in y_age])

# %%
input_shape = (128, 128, 1)

# %%
# Define the input shape for the model
inputs = Input((input_shape))

# Convolutional layers
# First convolutional layer with 32 filters, 3x3 kernel size, and ReLU activation
conv_1 = Conv2D(32, kernel_size=(3, 3), activation='relu')(inputs)
# First max pooling layer with 2x2 pool size
maxp_1 = MaxPooling2D(pool_size=(2, 2))(conv_1)

# Second convolutional layer with 64 filters, 3x3 kernel size, and ReLU activation
conv_2 = Conv2D(64, kernel_size=(3, 3), activation='relu')(maxp_1)
# Second max pooling layer with 2x2 pool size
maxp_2 = MaxPooling2D(pool_size=(2, 2))(conv_2)

# Third convolutional layer with 128 filters, 3x3 kernel size, and ReLU activation
conv_3 = Conv2D(128, kernel_size=(3, 3), activation='relu')(maxp_2)
# Third max pooling layer with 2x2 pool size
maxp_3 = MaxPooling2D(pool_size=(2, 2))(conv_3)

# Fourth convolutional layer with 256 filters, 3x3 kernel size, and ReLU activation
conv_4 = Conv2D(256, kernel_size=(3, 3), activation='relu')(maxp_3)
# Fourth max pooling layer with 2x2 pool size
maxp_4 = MaxPooling2D(pool_size=(2, 2))(conv_4)

# Flatten the convolutional features to use them in dense layers
flatten = Flatten()(maxp_4)

# Fully connected (Dense) layers
# First dense layer with 256 neurons and ReLU activation
dense_1 = Dense(256, activation='relu')(flatten)
# Second dense layer with 256 neurons and ReLU activation
dense_2 = Dense(256, activation='relu')(flatten)

# Apply dropout (30% of neurons will be turned off) to prevent overfitting
dropout_1 = Dropout(0.3)(dense_1)
dropout_2 = Dropout(0.3)(dense_2)

# Output layers
# First output layer for gender prediction with 1 neuron and sigmoid activation
output_1 = Dense(1, activation='sigmoid', name='gender_out')(dropout_1)
# Second output layer for age prediction with 1 neuron and ReLU activation
num_age_ranges = len(age_ranges)
output_2 = Dense(num_age_ranges, activation='softmax', name='age_out')(dropout_2)


# Create the Keras model using the defined inputs and outputs
model = Model(inputs=[inputs], outputs=[output_1, output_2])

# Compile the model with the appropriate loss function and optimizer
# - 'binary_crossentropy' for gender output since it's a binary classification (male/female)
# - 'mae' (Mean Absolute Error) for age output since it's a regression problem
# - Use 'adam' optimizer (an adaptive optimizer that works well in most cases)
model.compile(loss=['binary_crossentropy', 'categorical_crossentropy'], optimizer='adam', metrics=['accuracy'])
y_age_range_one_hot = to_categorical(y_age_range, num_classes=num_age_ranges)

# %%
# plot the model
import pydot
print(pydot.__version__)

import graphviz
print(graphviz.__version__)

from tensorflow.keras.utils import plot_model
plot_model(model)
# Out:
# 1.4.2
# 0.20.1
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
history = model.fit(x=X, y=[y_gender, y_age_range_one_hot], batch_size=32, epochs=30, validation_split=0.2)
# Out:
# Epoch 1/30
# 593/593 [==============================] - 377s 627ms/step - loss: 1.8966 - gender_out_loss: 0.4282 - age_out_loss: 1.4683 - gender_out_accuracy: 0.7926 - age_out_accuracy: 0.4449 - val_loss: 8.7230 - val_gender_out_loss: 0.4474 - val_age_out_loss: 8.2756 - val_gender_out_accuracy: 0.7908 - val_age_out_accuracy: 0.0209
# Epoch 2/30
# 593/593 [==============================] - 331s 557ms/step - loss: 1.5286 - gender_out_loss: 0.2861 - age_out_loss: 1.2426 - gender_out_accuracy: 0.8734 - age_out_accuracy: 0.4928 - val_loss: 8.9974 - val_gender_out_loss: 0.4361 - val_age_out_loss: 8.5613 - val_gender_out_accuracy: 0.8129 - val_age_out_accuracy: 0.0418
# Epoch 3/30
# 593/593 [==============================] - 348s 587ms/step - loss: 1.4056 - gender_out_loss: 0.2468 - age_out_loss: 1.1588 - gender_out_accuracy: 0.8944 - age_out_accuracy: 0.5144 - val_loss: 9.4688 - val_gender_out_loss: 0.4069 - val_age_out_loss: 9.0619 - val_gender_out_accuracy: 0.8172 - val_age_out_accuracy: 0.0510
# Epoch 4/30
# 593/593 [==============================] - 347s 584ms/step - loss: 1.3204 - gender_out_loss: 0.2201 - age_out_loss: 1.1004 - gender_out_accuracy: 0.9090 - age_out_accuracy: 0.5322 - val_loss: 11.2712 - val_gender_out_loss: 0.3843 - val_age_out_loss: 10.8869 - val_gender_out_accuracy: 0.8216 - val_age_out_accuracy: 0.0833
# Epoch 5/30
# 593/593 [==============================] - 345s 581ms/step - loss: 1.2472 - gender_out_loss: 0.2014 - age_out_loss: 1.0457 - gender_out_accuracy: 0.9139 - age_out_accuracy: 0.5495 - val_loss: 11.4218 - val_gender_out_loss: 0.4015 - val_age_out_loss: 11.0203 - val_gender_out_accuracy: 0.8414 - val_age_out_accuracy: 0.0588
# Epoch 6/30
# 593/593 [==============================] - 376s 635ms/step - loss: 1.1776 - gender_out_loss: 0.1815 - age_out_loss: 0.9961 - gender_out_accuracy: 0.9235 - age_out_accuracy: 0.5660 - val_loss: 13.5511 - val_gender_out_loss: 0.4062 - val_age_out_loss: 13.1449 - val_gender_out_accuracy: 0.8406 - val_age_out_accuracy: 0.1078
# Epoch 7/30
# 593/593 [==============================] - 375s 632ms/step - loss: 1.1171 - gender_out_loss: 0.1647 - age_out_loss: 0.9524 - gender_out_accuracy: 0.9331 - age_out_accuracy: 0.5842 - val_loss: 15.7160 - val_gender_out_loss: 0.4271 - val_age_out_loss: 15.2890 - val_gender_out_accuracy: 0.8505 - val_age_out_accuracy: 0.0759
# Epoch 8/30
# 593/593 [==============================] - 381s 642ms/step - loss: 1.0458 - gender_out_loss: 0.1500 - age_out_loss: 0.8958 - gender_out_accuracy: 0.9396 - age_out_accuracy: 0.6136 - val_loss: 13.9596 - val_gender_out_loss: 0.4278 - val_age_out_loss: 13.5318 - val_gender_out_accuracy: 0.8448 - val_age_out_accuracy: 0.1067
# Epoch 9/30
# 593/593 [==============================] - 365s 616ms/step - loss: 0.9773 - gender_out_loss: 0.1304 - age_out_loss: 0.8469 - gender_out_accuracy: 0.9485 - age_out_accuracy: 0.6302 - val_loss: 15.2346 - val_gender_out_loss: 0.4908 - val_age_out_loss: 14.7438 - val_gender_out_accuracy: 0.8477 - val_age_out_accuracy: 0.1111
# Epoch 10/30
# 593/593 [==============================] - 373s 630ms/step - loss: 0.9157 - gender_out_loss: 0.1156 - age_out_loss: 0.8002 - gender_out_accuracy: 0.9520 - age_out_accuracy: 0.6492 - val_loss: 17.2320 - val_gender_out_loss: 0.4918 - val_age_out_loss: 16.7403 - val_gender_out_accuracy: 0.8361 - val_age_out_accuracy: 0.1023
# Epoch 11/30
# 593/593 [==============================] - 348s 586ms/step - loss: 0.8396 - gender_out_loss: 0.0990 - age_out_loss: 0.7406 - gender_out_accuracy: 0.9590 - age_out_accuracy: 0.6770 - val_loss: 20.8293 - val_gender_out_loss: 0.6595 - val_age_out_loss: 20.1698 - val_gender_out_accuracy: 0.8446 - val_age_out_accuracy: 0.1324
# Epoch 12/30
# 593/593 [==============================] - 325s 548ms/step - loss: 0.7803 - gender_out_loss: 0.0892 - age_out_loss: 0.6911 - gender_out_accuracy: 0.9654 - age_out_accuracy: 0.6993 - val_loss: 21.6251 - val_gender_out_loss: 0.6311 - val_age_out_loss: 20.9939 - val_gender_out_accuracy: 0.8505 - val_age_out_accuracy: 0.1175
# Epoch 13/30
# 593/593 [==============================] - 299s 505ms/step - loss: 0.7129 - gender_out_loss: 0.0763 - age_out_loss: 0.6365 - gender_out_accuracy: 0.9700 - age_out_accuracy: 0.7205 - val_loss: 24.6448 - val_gender_out_loss: 0.7606 - val_age_out_loss: 23.8842 - val_gender_out_accuracy: 0.8480 - val_age_out_accuracy: 0.1141
# Epoch 14/30
# 593/593 [==============================] - 308s 520ms/step - loss: 0.6554 - gender_out_loss: 0.0674 - age_out_loss: 0.5880 - gender_out_accuracy: 0.9733 - age_out_accuracy: 0.7451 - val_loss: 26.1752 - val_gender_out_loss: 0.9023 - val_age_out_loss: 25.2729 - val_gender_out_accuracy: 0.8323 - val_age_out_accuracy: 0.1014
# Epoch 15/30
# 593/593 [==============================] - 300s 506ms/step - loss: 0.6122 - gender_out_loss: 0.0594 - age_out_loss: 0.5528 - gender_out_accuracy: 0.9774 - age_out_accuracy: 0.7642 - val_loss: 25.3387 - val_gender_out_loss: 0.7393 - val_age_out_loss: 24.5994 - val_gender_out_accuracy: 0.8391 - val_age_out_accuracy: 0.0900
# Epoch 16/30
# 593/593 [==============================] - 295s 497ms/step - loss: 0.5700 - gender_out_loss: 0.0578 - age_out_loss: 0.5123 - gender_out_accuracy: 0.9767 - age_out_accuracy: 0.7797 - val_loss: 28.9970 - val_gender_out_loss: 0.9161 - val_age_out_loss: 28.0809 - val_gender_out_accuracy: 0.8473 - val_age_out_accuracy: 0.1122
# Epoch 17/30
# 593/593 [==============================] - 294s 496ms/step - loss: 0.5231 - gender_out_loss: 0.0499 - age_out_loss: 0.4732 - gender_out_accuracy: 0.9795 - age_out_accuracy: 0.7930 - val_loss: 32.2110 - val_gender_out_loss: 1.1101 - val_age_out_loss: 31.1009 - val_gender_out_accuracy: 0.8410 - val_age_out_accuracy: 0.1023
# Epoch 18/30
# 593/593 [==============================] - 292s 493ms/step - loss: 0.4848 - gender_out_loss: 0.0456 - age_out_loss: 0.4392 - gender_out_accuracy: 0.9834 - age_out_accuracy: 0.8135 - val_loss: 33.6780 - val_gender_out_loss: 0.9691 - val_age_out_loss: 32.7089 - val_gender_out_accuracy: 0.8465 - val_age_out_accuracy: 0.1000
# Epoch 19/30
# 593/593 [==============================] - 298s 503ms/step - loss: 0.4577 - gender_out_loss: 0.0423 - age_out_loss: 0.4154 - gender_out_accuracy: 0.9841 - age_out_accuracy: 0.8206 - val_loss: 37.8821 - val_gender_out_loss: 1.1701 - val_age_out_loss: 36.7120 - val_gender_out_accuracy: 0.8429 - val_age_out_accuracy: 0.0903
# Epoch 20/30
# 593/593 [==============================] - 296s 499ms/step - loss: 0.4423 - gender_out_loss: 0.0419 - age_out_loss: 0.4003 - gender_out_accuracy: 0.9839 - age_out_accuracy: 0.8319 - val_loss: 35.1701 - val_gender_out_loss: 1.0097 - val_age_out_loss: 34.1604 - val_gender_out_accuracy: 0.8435 - val_age_out_accuracy: 0.0814
# Epoch 21/30
# 593/593 [==============================] - 307s 517ms/step - loss: 0.4082 - gender_out_loss: 0.0356 - age_out_loss: 0.3727 - gender_out_accuracy: 0.9863 - age_out_accuracy: 0.8447 - val_loss: 38.3980 - val_gender_out_loss: 1.2559 - val_age_out_loss: 37.1422 - val_gender_out_accuracy: 0.8364 - val_age_out_accuracy: 0.0922
# Epoch 22/30
# 593/593 [==============================] - 342s 576ms/step - loss: 0.3871 - gender_out_loss: 0.0321 - age_out_loss: 0.3550 - gender_out_accuracy: 0.9876 - age_out_accuracy: 0.8510 - val_loss: 42.4870 - val_gender_out_loss: 1.4921 - val_age_out_loss: 40.9949 - val_gender_out_accuracy: 0.8404 - val_age_out_accuracy: 0.0955
# Epoch 23/30
# 593/593 [==============================] - 350s 590ms/step - loss: 0.3717 - gender_out_loss: 0.0341 - age_out_loss: 0.3376 - gender_out_accuracy: 0.9869 - age_out_accuracy: 0.8593 - val_loss: 38.6655 - val_gender_out_loss: 1.2211 - val_age_out_loss: 37.4444 - val_gender_out_accuracy: 0.8458 - val_age_out_accuracy: 0.1137
# Epoch 24/30
# 593/593 [==============================] - 338s 569ms/step - loss: 0.3543 - gender_out_loss: 0.0312 - age_out_loss: 0.3231 - gender_out_accuracy: 0.9882 - age_out_accuracy: 0.8653 - val_loss: 39.4048 - val_gender_out_loss: 1.1928 - val_age_out_loss: 38.2120 - val_gender_out_accuracy: 0.8406 - val_age_out_accuracy: 0.1122
# Epoch 25/30
# 593/593 [==============================] - 366s 618ms/step - loss: 0.3535 - gender_out_loss: 0.0342 - age_out_loss: 0.3194 - gender_out_accuracy: 0.9885 - age_out_accuracy: 0.8680 - val_loss: 38.0844 - val_gender_out_loss: 1.1155 - val_age_out_loss: 36.9690 - val_gender_out_accuracy: 0.8391 - val_age_out_accuracy: 0.1101
# Epoch 26/30
# 593/593 [==============================] - 351s 592ms/step - loss: 0.3380 - gender_out_loss: 0.0315 - age_out_loss: 0.3065 - gender_out_accuracy: 0.9878 - age_out_accuracy: 0.8714 - val_loss: 38.7447 - val_gender_out_loss: 1.1756 - val_age_out_loss: 37.5691 - val_gender_out_accuracy: 0.8444 - val_age_out_accuracy: 0.1075
# Epoch 27/30
# 593/593 [==============================] - 313s 528ms/step - loss: 0.3334 - gender_out_loss: 0.0339 - age_out_loss: 0.2995 - gender_out_accuracy: 0.9877 - age_out_accuracy: 0.8773 - val_loss: 41.7224 - val_gender_out_loss: 1.1841 - val_age_out_loss: 40.5383 - val_gender_out_accuracy: 0.8408 - val_age_out_accuracy: 0.0909
# Epoch 28/30
# 593/593 [==============================] - 325s 548ms/step - loss: 0.3052 - gender_out_loss: 0.0277 - age_out_loss: 0.2774 - gender_out_accuracy: 0.9887 - age_out_accuracy: 0.8882 - val_loss: 42.1760 - val_gender_out_loss: 1.2577 - val_age_out_loss: 40.9183 - val_gender_out_accuracy: 0.8414 - val_age_out_accuracy: 0.0833
# Epoch 29/30
# 593/593 [==============================] - 324s 546ms/step - loss: 0.3107 - gender_out_loss: 0.0294 - age_out_loss: 0.2814 - gender_out_accuracy: 0.9885 - age_out_accuracy: 0.8855 - val_loss: 41.9946 - val_gender_out_loss: 1.3045 - val_age_out_loss: 40.6900 - val_gender_out_accuracy: 0.8391 - val_age_out_accuracy: 0.1059
# Epoch 30/30
# 593/593 [==============================] - 311s 525ms/step - loss: 0.2984 - gender_out_loss: 0.0271 - age_out_loss: 0.2713 - gender_out_accuracy: 0.9897 - age_out_accuracy: 0.8891 - val_loss: 42.8093 - val_gender_out_loss: 1.2987 - val_age_out_loss: 41.5106 - val_gender_out_accuracy: 0.8524 - val_age_out_accuracy: 0.0978

# %%
model.save('TrainedModelV3.h5')

# %%
image_index = 344
pred = model.predict(X[image_index].reshape(1, 128, 128, 1))
pred_gender = round(pred[0][0][0])
age_probs = pred[1][0]

print("Original Gender:", y_gender[image_index], "Original Age Range:", age_ranges[age_to_range(y_age[image_index])])
print("Predicted Gender:", pred_gender)
print("Probabilities for each age range:")

for i, prob in enumerate(age_probs):
    print("Age Range {}: {:0.2%}".format(age_ranges[i], prob))
# Out:
# 1/1 [==============================] - 0s 310ms/step
# Original Gender: 1 Original Age Range: (6, 12)
# Predicted Gender: 1
# Probabilities for each age range:
# Age Range (0, 2): 0.00%
# Age Range (3, 5): 0.13%
# Age Range (6, 12): 99.81%
# Age Range (13, 17): 0.01%
# Age Range (18, 24): 0.05%
# Age Range (25, 34): 0.00%
# Age Range (35, 44): 0.00%
# Age Range (45, 54): 0.00%
# Age Range (55, 64): 0.00%
# Age Range (65, 74): 0.00%
# Age Range (75, 100): 0.00%
